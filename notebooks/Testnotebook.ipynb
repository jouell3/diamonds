# %%
# NB : This reload your library after each edit, 
# so you don't have to restart the kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from diamonds.data import load_data, clean_data, create_X_y, split

# %%
df_diamonds = load_data()

# %%
df_clean = clean_data(df_diamonds)

# %%
X, y = create_X_y(df_clean)

# %%
X_train, X_test, y_train, y_test = split(X, y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((40440, 9), (13480, 9), (40440,), (13480,))
